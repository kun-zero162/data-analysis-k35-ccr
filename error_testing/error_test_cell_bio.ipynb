# %% [markdown]
# # CellBio task generation

# %%
# General importations.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import string
from random import shuffle,seed,choices
from faker import Faker
from faker.providers.person.en import Provider
import networkx as nx
import itertools

from utils import Utils
from cell_bio import CellBio
from dataset_generator import DataSetGenerator

# %%
u = Utils()
dg = DataSetGenerator()

# %% [markdown]
# ## Error test (low complexity)

# %%
size = [[2,2,2],[2,2,2]]
tg = CellBio(n_per_bcc = size, 
             bcc_types = [["cycle"]*len(size[0])]*len(size))

print("\n- Global cause-effect pairs:", tg.get_global())
print("\n- Local cause-effect pairs:", tg.get_local())
print("\n- Compositions:", tg.get_compositions())
# Out:
# - Global cause-effect pairs: ('5BUM', 'BOPB')
#
# - Local cause-effect pairs: {0: [('5BUM', 'FACA'), ('5BUM', 'X9LX'), ('FACA', 'X9LX'), ('FACA', 'BOPB'), ('X9LX', 'BOPB')], 1: [('5BUM', 'D7Z2'), ('5BUM', 'QGN6'), ('D7Z2', 'QGN6'), ('D7Z2', 'BOPB'), ('QGN6', 'BOPB')]}
#
# - Compositions: {0: [[('5BUM', 'FACA'), ('FACA', 'X9LX'), ('X9LX', 'BOPB')], [('5BUM', 'FACA'), ('FACA', 'BOPB')], [('5BUM', 'X9LX'), ('X9LX', 'BOPB')]], 1: [[('5BUM', 'D7Z2'), ('D7Z2', 'QGN6'), ('QGN6', 'BOPB')], [('5BUM', 'D7Z2'), ('D7Z2', 'BOPB')], [('5BUM', 'QGN6'), ('QGN6', 'BOPB')]]}

# %%
for key,g in tg.subgraph_dict.items():
    u.plot_nx(nx.to_numpy_array(g), 
              labels = list(g.nodes),
              figsize = (3,3), 
              dpi = 60)

for key,cct in tg.cct.items():
    u.plot_nx(nx.to_numpy_array(cct), 
              labels = list(cct.nodes),
              figsize = (3,3), 
              dpi = 60)

print("\nCCT topo sorts:", tg.cct_sort)
print("\nCompositions:", tg.comp_dict)
print("\nCompositions:", tg.compositions)
print("\nCutpoints:", tg.cutpoint_dict)
print("\nCutpoints:", tg.cutpoints)
print("\nUnique paths in CCTs:", tg.path_dict)
print("\nExogenous variables:", tg.exog_names)
print("\nEndogenous variables:", tg.nodes)
print("\nDirect effects / edge coefficients:", tg.direct_effects)
# Out:
# CCT topo sorts: {0: ['5BUM', 'FACA', 'X9LX', 'BOPB'], 1: ['5BUM', 'D7Z2', 'QGN6', 'BOPB']}
#
# Compositions: {0: [[('5BUM', 'FACA'), ('FACA', 'X9LX'), ('X9LX', 'BOPB')], [('5BUM', 'FACA'), ('FACA', 'BOPB')], [('5BUM', 'X9LX'), ('X9LX', 'BOPB')]], 1: [[('5BUM', 'D7Z2'), ('D7Z2', 'QGN6'), ('QGN6', 'BOPB')], [('5BUM', 'D7Z2'), ('D7Z2', 'BOPB')], [('5BUM', 'QGN6'), ('QGN6', 'BOPB')]]}
#
# Compositions: {0: [[('5BUM', 'FACA'), ('FACA', 'X9LX'), ('X9LX', 'BOPB')], [('5BUM', 'FACA'), ('FACA', 'BOPB')], [('5BUM', 'X9LX'), ('X9LX', 'BOPB')]], 1: [[('5BUM', 'D7Z2'), ('D7Z2', 'QGN6'), ('QGN6', 'BOPB')], [('5BUM', 'D7Z2'), ('D7Z2', 'BOPB')], [('5BUM', 'QGN6'), ('QGN6', 'BOPB')]]}
#
# Cutpoints: {0: ['FACA', 'X9LX'], 1: ['D7Z2', 'QGN6']}
#
# Cutpoints: {0: ['FACA', 'X9LX'], 1: ['D7Z2', 'QGN6']}
#
# Unique paths in CCTs: {0: [['5BUM', 'FACA', 'X9LX', 'BOPB'], ['5BUM', 'FACA', 'BOPB'], ['5BUM', 'X9LX', 'BOPB'], ['5BUM', 'BOPB']], 1: [['5BUM', 'D7Z2', 'QGN6', 'BOPB'], ['5BUM', 'D7Z2', 'BOPB'], ['5BUM', 'QGN6', 'BOPB'], ['5BUM', 'BOPB']]}
#
# Exogenous variables: ['AXIH', '6AUG', 'A2NU', '1850', '89EV', '6FSX']
#
# Endogenous variables: ['5BUM', 'FACA', 'X9LX', 'BOPB', 'D7Z2', 'QGN6']
#
# Direct effects / edge coefficients: {('5BUM', 'FACA'): 1.3, ('5BUM', 'D7Z2'): 3.3, ('5BUM', 'BOPB'): 0.3, ('FACA', 'X9LX'): 3.5, ('X9LX', 'BOPB'): 0.8, ('D7Z2', 'QGN6'): 1.3, ('QGN6', 'BOPB'): 3.3}

# %%
context = tg.get_causal_context()
sample_context = tg.get_sample_context(n_extra_vars = 5)
print()
print("Context:", context)
print()
print("Sample context:", sample_context)
print()
# Out:
# Context: A cellular biologist is studying the impacts of exposure to compound D3RPYO on transcription and translation in cell type 922THI of organism HBVB9D. When stilumated with compound D3RPYO, cell type 922THI The cell will produce mRNA transcripts for gene 5BUMthe current volume of enzyme AXIH.  When stimulated with compound D3RPYO, cell type 922THI will produce mRNA transcripts for gene FACA equal in volume to the current volume of enzyme 6AUG.the current volume of enzyme AXIH.  When stimulated with compound D3RPYO, cell type 922THI will produce mRNA transcripts for gene X9LX equal in volume to the current volume of enzyme A2NU.the current volume of enzyme AXIH. The cell will produce mRNA transcripts for gene BOPBthe current volume of enzyme 1850.  When stimulated with compound D3RPYO, cell type 922THI will produce mRNA transcripts for gene D7Z2 equal in volume to the current volume of enzyme 89EV.the current volume of enzyme 1850.  When stimulated with compound D3RPYO, cell type 922THI will produce mRNA transcripts for gene QGN6 equal in volume to the current volume of enzyme 6FSX.the current volume of enzyme 1850. Assume that all factorus influencing the transcription and translation of these macromolecules are fully described here.
#
# Sample context: At the time of the experiment, the biologist measures0.28905159251485646 pg of enzyme 6AUG, 1.7922770178627108 pg of enzyme AXIH, 1.4544814371423245 pg of enzyme QM8S, 0.7896472116801493 pg of enzyme A2NU, 0.2968346188495791 pg of enzyme 6FSX, 2.384373287950964 pg of enzyme 53DB, 2.9716457778066077 pg of enzyme 4BNJ, 2.4350989692271523 pg of enzyme 1850, 1.637968106940117 pg of enzyme 8ZFJ, 0.5883899098425941 pg of enzyme YG31 and 1.1214883938069065 pg of enzyme 89EV.

# %%
print()
print("- Factual queries:")
display(tg.get_factual_queries())
# Out:
# - Factual queries:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 print()
#       2 print("- Factual queries:")
# ----> 3 display(tg.get_factual_queries())
#
# File ~/Desktop/cornell/ccr/cell_bio.py:400, in CellBio.get_factual_queries(self)
#     398 self.f_query_dict = dict()
#     399 outro = " Begin your response with Yes or No and be as concise as possible."
# --> 400 for pair in [self.global_quantity]+self.local:
#     401     effect = pair[1]
#     402     if effect != "surgery":
#
# TypeError: can only concatenate list (not "dict") to list

# %%
cf_1, cf_0 = tg.get_counterfactual_queries()
print("- Counterfactual queries (cause = True):")
for key,val in cf_1.items():
    print("\n-----------------------")
    print("\n-- {} --".format(key))
    print("Prompt:", val.get("Prompt"))
    print("True endogenous:", val.get("True endogenous"))
    print("True exogenous:", val.get("True exogenous"))
    print("True response:", val.get("True response"))
print("\n-----------------------")

# %%
print("- Counterfactual queries (cause = False):")
for key,val in cf_0.items():
    print("\n-----------------------")
    print("\n-- {} --".format(key))
    print("Prompt:", val.get("Prompt"))
    print("True endogenous:", val.get("True endogenous"))
    print("True exogenous:", val.get("True exogenous"))
    print("True response:", val.get("True response"))
print("\n-----------------------")

# %%
# Test observational data generation.
df_obs, df_noise = tg.sample_scm(n = 5,
                                 intervene_node = None,
                                 intervene_value = 0)
display(df_obs.head())
display(df_noise.head())

# %%
# Test counterfactual data generation.
causes = set([x[0] for x in [tg.get_global()]+tg.get_local()])
intervene_value = 1
for cause in causes:
    print("\n-- {} = {} --".format(cause,intervene_value))
    df_obs, df_noise = tg.sample_scm(n = 5,
                                     intervene_node = cause,
                                     intervene_value = intervene_value)
    display(df_obs.head())
    display(df_noise.head())

# %%
# Test counterfactual data generation.
causes = set([x[0] for x in [tg.get_global()]+tg.get_local()])
intervene_value = 0
for cause in causes:
    print("\n-- {} = {} --".format(cause,intervene_value))
    df_obs, df_noise = tg.sample_scm(n = 5,
                                     intervene_node = cause,
                                     intervene_value = intervene_value)
    display(df_obs.head())
    display(df_noise.head())

# %% [markdown]
# ## Error test (moderate complexity)

# %%
size = [[3,3],[3,3],[3,3]]
tg = CellBio(n_per_bcc = size, 
                   bcc_types = ["cycle"]*len(size))
'''
context = tg.get_causal_context()
sample_context = tg.get_sample_context(n_extra_vars = 2)
print()
print("Context:", context)
print()
print("Sample context:", sample_context)
print()
print("- Global cause-effect pairs:", tg.get_global())
print("- Local cause-effect pairs:", tg.get_local())
print("- Compositions:", tg.get_compositions())
'''

# %%
print()
print("- Factual queries:")
display(tg.get_factual_queries())

# %%
cf_1, cf_0 = tg.get_counterfactual_queries()
print("- Counterfactual queries (cause = True):")
for key,val in cf_1.items():
    print("\n-----------------------")
    print("\n-- {} --".format(key))
    print("Prompt:", val.get("Prompt"))
    print("True endogenous:", val.get("True endogenous"))
    print("True exogenous:", val.get("True exogenous"))
    print("True response:", val.get("True response"))
print("\n-----------------------")

# %%
print("- Counterfactual queries (cause = False):")
for key,val in cf_0.items():
    print("\n-----------------------")
    print("\n-- {} --".format(key))
    print("Prompt:", val.get("Prompt"))
    print("True endogenous:", val.get("True endogenous"))
    print("True exogenous:", val.get("True exogenous"))
    print("True response:", val.get("True response"))
print("\n-----------------------")

# %%
# Test observational data generation.
df_obs, df_noise = tg.sample_scm(n = 5,
                                 intervene_node = None,
                                 intervene_value = 0)
display(df_obs.head())
display(df_noise.head())

# %%
# Test counterfactual data generation.
causes = set([x[0] for x in [tg.get_global()]+tg.get_local()])
intervene_value = 1
for cause in causes:
    print("\n-- {} = {} --".format(cause,intervene_value))
    df_obs, df_noise = tg.sample_scm(n = 5,
                                     intervene_node = cause,
                                     intervene_value = intervene_value)
    display(df_obs.head())
    display(df_noise.head())

# %%
# Test counterfactual data generation.
causes = set([x[0] for x in [tg.get_global()]+tg.get_local()])
intervene_value = 0
for cause in causes:
    print("\n-- {} = {} --".format(cause,intervene_value))
    df_obs, df_noise = tg.sample_scm(n = 5,
                                     intervene_node = cause,
                                     intervene_value = intervene_value)
    display(df_obs.head())
    display(df_noise.head())

# %%
glo = [tg.get_global()]
loc = tg.get_local()
comp = tg.get_compositions()

print(glo)
print(loc)
print(comp)

# %%
# Get PNS and compare to ATE.
results_dict = dict()
for n in [5,10,50,100,500,1000,5000]:
    pair_dict = dict()
    for pair in glo+loc:
        df_cf, df_noise = tg.sample_scm(n = n,
                                        intervene_node = pair[0],
                                        intervene_value = 1)
        df_cf.rename(columns={pair[1]: 'True (cause = True)'}, inplace = True)
        df_cf_0, df_noise = tg.sample_scm(n = n,
                                          intervene_node = pair[0],
                                          intervene_value = 0)
        df_cf["True (cause = False)"] = df_cf_0[pair[1]]
        display(df_cf.head(5))
        print("\n-- {} | n = {} --".format(pair,n))
        pns = dg.get_pns_ate(df_cf)
        pair_dict[pair] = pns
    results_dict[n] = pair_dict

# %%
for n,res in results_dict.items():
    print("\n-- n = {} --".format(n))
    comp_pns = 1
    for pair,pns in res.items():
        if pair == glo[0]:
            global_pns = pns
        else:
            comp_pns *= pns
    print("Global PNS  =", global_pns)
    print("Composition =", comp_pns)

# %%
results_dict

# %% [markdown]
# ## Error test (high complexity)

# %%
size = [[3,5],[3,4,3],[4,4,4]]
tg = CellBio(n_per_bcc = size, 
                   bcc_types = ["wheel"]*len(size))
'''
context = tg.get_causal_context()
sample_context = tg.get_sample_context(n_extra_vars = 2)
print()
print("Context:", context)
print()
print("Sample context:", sample_context)
print()
print("- Global cause-effect pairs:", tg.get_global())
print("- Local cause-effect pairs:", tg.get_local())
print("- Compositions:", tg.get_compositions())
'''

# %%
print(tg.exog_names)
print(tg.exog_true_binary)
print(tg.alleles_obs)
print(tg.fam_hist_obs)
print(tg.prev_surg_obs)

# %% [markdown]
# ## Generate dataset

# %%
# x levels of graphical complexity (captured by BCC size).
# y tasks per graphical complexity level.
# z samples per task.
# w replicates per sample.
# = x*y*z*w subtasks.
graph_sizes = [[2,2],[3,3],[4,4]]
n_tasks_per_size = 3
n_samples_per_task = 1000
reps_per_sample = 5

df = dg.get_dataset(task_generator = CellBio,
                    graph_sizes = graph_sizes,
                    n_tasks_per_size = n_tasks_per_size,
                    n_samples_per_task = n_samples_per_task, 
                    reps_per_sample = reps_per_sample)

display(df)

# %%
# Process prompts.
df_factual, df_cf = dg.process_prompts()
display(df_factual)
display(df_cf)

# %%
pns_dict = dg.get_pns_dict(verbose = True)
pns_dict

# %%
threshold_dict = dg.get_internal_consistency_thresholds(multiplier = 1.25)
threshold_dict

# %%
# Test save and load with numpy.
np.save("clinical_notes_threshold_dict.npy", threshold_dict) 
read_dictionary = np.load("clinical_notes_threshold_dict.npy",
                          allow_pickle = "TRUE").item()
display(read_dictionary)

# %%
df_cf[df_cf["Context ID"] == 0]

# %%
df_cf[(df_cf["Context ID"] == 0) & (df_cf["Cause-effect pair"] == ("pain", "surgery"))]

# %%
df_cf[(df_cf["Context ID"] == 1) & (df_cf["Cause-effect pair"] == ("pain", "surgery"))]

# %% [markdown]
# ## End of document
